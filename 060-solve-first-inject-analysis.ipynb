# %% [markdown]
# # Solve First and Inject Error Analysis
# Performs the experiments about how often the LLM solves first and then injects an error in the the correct solution path (see Discussion in paper)
