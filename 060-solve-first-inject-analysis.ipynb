# %% [markdown]
# # Solve First and Inject Error Analysis
#
# This notebook computes the solve-first / inject-from-solution numbers reported in Section 4.3 and Appendix C.1 (95.2% of traces construct a step-by-step solution first; of those, 73.8% diverge at a specific step to inject an error), via the `SOLVE_FIRST`/`INJECT_FROM_SOLUTION` automatic annotation prompt in appendix Table 20.
#
# TODO: clean and publish underlying code
