# %% [markdown]
# # Error Simulation: Process Analysis
# Qualitative analysis of *how* the LLM simulates student errors conditioned on a misconception --
# looking at the reasoning trace rather than just the final answer (Appendix C.2 "Trace level analysis";
# cited in Section 4.3, "Comparison with literature best practices").
#
# TODO: clean and publish underlying code for the two analyses below (see their TODOs for the exact spec).
